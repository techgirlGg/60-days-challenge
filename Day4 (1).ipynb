# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download required NLTK data (run once)
nltk.download('punkt')
nltk.download('stopwords')

def clean_text(text):
    # 1. Convert text to lowercase
    text = text.lower()
    
    # 2. Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # 3. Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # 4. Tokenize text into words
    words = word_tokenize(text)
    
    # 5. Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    
    # 6. Join words back into sentence
    cleaned_text = " ".join(filtered_words)
    
    return cleaned_text


# Example Input
text = "Hello!!! This is a sample text, with numbers 123 and punctuation marks."

# Output
print("Original Text:")
print(text)

print("\nCleaned Text:")
print(clean_text(text))
# Out:
# Original Text:
# Hello!!! This is a sample text, with numbers 123 and punctuation marks.
#
# Cleaned Text:
# hello sample text numbers punctuation marks
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
